# %%
# Automatically reloads imported files: this is not done manually by ipynb; this magic command tells the compiler that each time we update an imported file we want to reload it
# %load_ext autoreload
# Reload all modules before executing code
# %autoreload 2

# %%
# Import the gtxDLClass
# %pip install dicttoxml
# %pip install s3path
from temp_rooaa import DL
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\Hikaru Kurosawa\Documents\GitHub\gtxDLPythonCode\temp_rooaa.py:408: SyntaxWarning: invalid escape sequence '\L'
#   loadFile = input('Enter the general and specific directory (e.g. meshLRTests\\\LR2e-5) pertaining to the .h5 (weights) file you would like to load: ')
# c:\Users\Hikaru Kurosawa\Documents\GitHub\gtxDLPythonCode\temp_rooaa.py:512: SyntaxWarning: invalid escape sequence '\L'
#   loadFile = input('Enter the general and specific directory (e.g. meshLRTests\\\LR2e-5) pertaining to the .h5 (weights) file you would like to load: ')

# %% [markdown]
# ## Background
#
# In the above cell I import the DL class, which is written in a script called gtxDLClass.py located in the same directory as this notebook: this class is designed to handle all of the functionality of the DL architecture, which was previously handled inside the notebook, in a more compact way so that the cells and the associated DL pipeline is more easily understandable.
#
# ## Instructions
#
# The DL class itself in gtxDLClass.py is full of comments and docstrings outlining the functionality of the various methods (methods are functions defined within a class) and algorithms involved in the DL process: if you want to understand some of the intricacies of the pipeline, or if you run into any errors, that's where you need to look.
#
# ## Functions
#
# Below is a list of gtxDLClass.py functions and their purposes are listed below:<br />
# **Initialization** <br />
# &emsp;name = DL()<br />
# **Training** <br />
# &emsp;name.Train()<br />
# **Testing** <br />
# &emsp;name.QuickTest()<br />
# &emsp;name.LoadandPredict()<br />
# **Analysis** <br />
# &emsp;*Full Analysis:* name.Analysis() <br />
# &emsp;*Print Inputs:* name.PrintImg()<br />
# &emsp;*Print DL Predictions:* name.Results()<br />
# &emsp;*Print Feature Maps:* name.PrintFeatureMap()<br />

# %%
test = DL()
# Out:
# Choose a bucket:
#  20240920-matthew
#  20241119-rooaa
#
# Choose a Default Parameters Case:
#  Default4Fx
#  Default6Fx_HighRes_SmallFOV
#  Default6Fx_LowRes_LargeFOV
#  Default6Fx_64x64
#
#
# Parameters:
# {'activation': 'relu', 'optimizer': 'Adam', 'epochs': 200, 'learningRate': 5e-05, 'scaleRE': 1, 'scaleDF': 1, 'nF': 6, 'xX': 101, 'yY': 101, 'batch': 32, 'decayRate': 0.3, 'nFilters3D': 128, 'nFilters2D': 128, 'kernelConv3D': (3, 3, 6), 'strideConv3D': (1, 1, 1), 'kernelResBlock3D': (3, 3, 6), 'kernelConv2D': (3, 3), 'strideConv2D': (1, 1), 'kernelResBlock2D': (3, 3)}

# %%
test.Train()

# %%
test.Plot()

# %%
test.QuickTest()

# %%
test.Model()
# Out:
# c:\Users\Hikaru Kurosawa\Documents\GitHub\gtxDLPythonCode\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Maxpool1:  (None, 50, 50, 64)
# Max_Pool_2:  (None, 25, 25, 256)
# Max_Pool_3:  (None, 12, 12, 512)
# Conv_2:  (None, 25, 25, 512)
# Up_conv_1:  (None, 24, 24, 512)
# Up_conv_1:  (None, 24, 24, 512)
# Up_conv_2:  (None, 48, 48, 256)
# Conv_1:  (None, 50, 50, 256)
# Up_conv_3:  (None, 100, 100, 128)
# inRE:  (None, 101, 101, 64)
# outDF shape (None, 101, 101, 1)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ...

# %%
test.LoadandPredict()
# Out:
# ModelParameters//temp//Default6Fx_LowRes_LargeFOV.keras
# TestingData/20241121_0.1xfHb_0.95xStO2_testing/DL_nImages50.mat
# TestingData/20241126_10xfHb_0.95xStO2_testing/DL_nImages50.mat
# TestingData/20241127_0.1xfHb_0.95xStO2_DL_Refl/DL_nImages100.mat
# TestingData/20241127_10xfHb_0.95xStO2_DL_Refl/DL_nImages100.mat
# TestingData/20241127_10xfHb_0.95xStO2_DL_Refl_2/DL_nImages100.mat
# TestingData/20241127_10xfHb_0.95xStO2_FixedRefl/DL_nImages100.mat
# TestingData/20241202_CSH_2x_Scattering/DL_nImages50.mat
# TestingData/20250115_1-5fHb_0.25-0.75StO2_TestSet/DL_nImages100.mat
# TestingData/20250127_1-5fHb_0.25-0.75StO2_MCX_5e7Photons/DL_nImages10000.mat
# TestingData/20250128_1-5fHb_0.25-0.75StO2_TestSet_100x100_1e7/DL_nImages100.mat
# TestingData/20250128_1-5fHb_0.25-0.75StO2_TestSet_100x100_1e8/DL_nImages100.mat
# TestingData/20250128_1-5fHb_0.25-0.75StO2_TestSet_100x100_5e7/DL_nImages100.mat
# TestingData/20250130_1-5fHb_0.25-0.75StO2_DT_100x100/DL_nImages100.mat
# ...

# %%
test.Analysis()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# <unknown>:408: SyntaxWarning: invalid escape sequence '\L'
# <unknown>:512: SyntaxWarning: invalid escape sequence '\L'
# <unknown>:408: SyntaxWarning: invalid escape sequence '\L'
# <unknown>:512: SyntaxWarning: invalid escape sequence '\L'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# (1, 101, 101)
# (1, 101, 101)
# Average Depth Error (SD): 8.5352(1.1593) mm
# Depth Mean Squared Error: 74.194 mm
# Overall Depth SSIM: 0.19198
# [np.float32(5.8417296)]
# [np.float32(10.0)]

# %%
test.importData(True, False)
# Out:
# TestingData/20240516_50_ShallowTumors_PpIX/DL_nImages50.mat
# TestingData/20240523_100_ShallowTumors_Larger/DL_nImages100.mat
# TestingData/20240813_CSH_5xfHB_0.5xStO2_TestSet/DL_nImages100.mat
# TestingData/20240813_Cyl_2xfHb_0.95StO2_TestSet2_2/DL_nImages100.mat
# TestingData/20241004_CSH_3xfHB_0.5xStO2_TestSet/DL_nImages100.mat
# TestingData/20241004_CSH_3xfHB_0.5xStO2_TestSet_recreation1/DL_nImages100.mat
# TestingData/20241011_CSH_2xfHB_0.5xStO2_LowContrast/DL_nImages100.mat
# TestingData/20241011_CSH_3.5xfHB_0.5xStO2_MedContrast/DL_nImages100.mat
# TestingData/20241011_CSH_5xfHB_0.5xStO2_HighContrast/DL_nImages100.mat
# TestingData/20241024_CSH_3xfHb_0.5xStO2_COLOUR/DL_nImages100.mat
# TestingData/20241118_CSH_3xfHb_0.5xStO2_SmallHigh_MCX/DL_nImages100.mat
# TestingData/20241118_CSH_3xfHb_0.5xStO2_SmallHigh_MCX/DL_nImages100_cropped.mat
# TestingData/20241118_CSH_3xfHb_0.5xStO2_SmallHigh_MCX/DL_nImages100_cropped64.mat
# ...

# %%
test.PrintImg()
# Out:
# Choose the input/output map you want to display (RE, DF): RE
# Choose how many tumours you want to view: 4
# Do you want to normalize? [0/1]: 0

# %%
test.Analysis()

# %%
test.importData(True,False)

# %%
test.Model()

# %%
# !df -h

# %%
# !du -sh /home/ec2-user/SageMaker/*

# %%
# !du -sh /home/ec2-user/SageMaker/ModelParameters/*

# %%
# !du -ah /home/ec2-user/SageMaker | sort -rh | head -n 10

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0
